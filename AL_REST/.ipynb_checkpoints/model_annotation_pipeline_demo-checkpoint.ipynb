# %% [markdown]
# # Annotation Pipeline
# This notebook runs through typical steps in the model annotation pipeline and mocks the expected communcation with the active learning API as far as presentable within this notebook. It requires the AL_REST docker container to be running. The path that documents take between the work packages is as follows:
#
# 1. **AP2:** Documents get added to collection
# * **AP2->AP4:** Collection including new documents gets annotated by segment detection model, which creates segments
# * **AP4->AP3:** Additional text classification is performed and added to the segments
# * **AP3->AP2:** Segment annotations are added to the documents in the collection
# * **AP2 (Active Learning):** Importance score is calculated for each annotation and, based on that, each document
# * **AP2 (Active Learning) -> AP2 (Annotation Tool):** Most important documents are selected and passed to the annotation tool
# * **AP2 (Annotation Tool):** Annotation is performed by human annotators and documents updated
# * **AP2 (Annotation Tool) -> AP2 (Active Learning):** Documents in collection are updated with human annotation
#
# Since there is no machine learning as of yet, the process stops here.

# %% [markdown]
# ## Initialization
# In a first step, model names and used documents (xml and mocked) are defined and basic request functions are implemented.

# %%
from urllib import request, parse
import xml.etree.ElementTree as ET
import json
from pprint import pprint

ANNOTATION_BOUNDING_BOX = ("segment_boundary", "segment_detection_model")
ANNOTATION_SEGMENT_TYPE = ("segment_type", "segment_type_model")
ANNOTATION_TRUNCATION = ("is_truncated", "truncation_model")
ANNOTATION_OCCLUSION  = ("is_occluded", "occlusion_model")
ANNOTATOR_TYPE = "model"
DOCUMENT_NAMES = ["testdata/3ZCCCW.pdf", "testdata/01-Anfrage-Musterbrief_1.pdf"]
DB_PATH = "/home/tobias/data"

def post_json(data_in, url):
    data = json.dumps(data_in).encode('utf-8')
    req =  request.Request(url, data=data, headers={'content-type': 'application/json'}) # this will make the method "POST"
    resp = request.urlopen(req)
    resp_text = resp.read().decode('utf-8')
    return resp_text

def get_json(url):
    req =  request.Request(url, headers={})
    resp = request.urlopen(req)
    resp_text = resp.read().decode('utf-8')
    return resp_text

# %% [markdown]
# # 1. **AP2:** Documents get added to collection
# The documents are added to the active learning collection. At the moment they only consist of a document id and a single page (mocked without pdf). Models are already defined in a config file in the docker container.

# %%
"""
from shutil import copyfile
import os.path
for name in DOCUMENT_NAMES:
    copyfile(name, os.path.join(DB_PATH, name))"""

"""
def add_document(document_id):
    document = {
        "document_id": document_id,
        "pages":[{"page_number":0}]
    }
    
    url = "http://localhost:5000/add_document/"
    resp = post_json(document, url)
    print(resp)

for document_id in DOCUMENT_IDS:
    add_document(document_id)"""

url = "http://localhost:5000/start_pipeline/"

#url = "http://localhost:5000/set_document_ids/"
resp = post_json(DOCUMENT_NAMES, url)
print("Created Documents:", resp)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-6-e0feee1a2d14> in <module>
#      22
#      23 #url = "http://localhost:5000/set_document_ids/"
# ---> 24 resp = post_json(DOCUMENT_NAMES, url)
#      25 print("Created Documents:", resp)
#
# <ipython-input-2-5d627c94aa62> in post_json(data_in, url)
#      15     data = json.dumps(data_in).encode('utf-8')
#      16     req =  request.Request(url, data=data, headers={'content-type': 'application/json'}) # this will make the method "POST"
# ---> 17     resp = request.urlopen(req)
#      18     resp_text = resp.read().decode('utf-8')
#      19     return resp_text
#
# ~/.conda/envs/Python3.6/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~/.conda/envs/Python3.6/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# ~/.conda/envs/Python3.6/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# ~/.conda/envs/Python3.6/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     568         if http_err:
#     569             args = (dict, 'default', 'http_error_default') + orig_args
# --> 570             return self._call_chain(*args)
#     571
#     572 # XXX probably also want an abstract factory that knows when it makes
#
# ~/.conda/envs/Python3.6/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~/.conda/envs/Python3.6/lib/python3.6/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648 class HTTPDefaultErrorHandler(BaseHandler):
#     649     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 650         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     651
#     652 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 500: INTERNAL SERVER ERROR

# %% [markdown]
# # 2. **AP2->AP4:** Collection including new documents gets annotated by segment detection model, which creates segments
# ##  Getting document data from the server as the segement detection model
# After receiving the unlabeled documents, the model can annotate the pages. To be determined: how to send pdf file. This only happens this way for unlabeled documents. When machine learning is involved, labeled data (including partially labeled documents) needs to be considered and transferred differently.

# %%
# called from AP4, but should be the other way around
url = "http://localhost:5000/get_unlabeled_documents/"
document_dict = json.loads(get_json(url))
print(document_dict)

# TODO: How should control between AP containers be handled?
# instead have function in AP4 that AP2 can call to give document data to AP4?
# Out:
# {'dd459a615a1fb4da9b46d5da6f9eda88': {'document_id': 'dd459a615a1fb4da9b46d5da6f9eda88', 'importance_score': -1, 'document_label': {'group_id': 0, 'importance_score': -1, 'annotation_type': 'document_label', 'annotations': []}, 'pages': []}}

# %% [markdown]
# ## Get annotation types
# Here we just get the annotation types so that we can later get the right index for labeling segments.

# %%
url = "http://localhost:5000/get_annotation_types/"
annotation_types = json.loads(get_json(url))
annotation_types
# Out:
# {'segment_boundary': {'model_ids': ['segment_detection_model'],
#   'labels': ['xmin', 'ymin', 'xmax', 'ymax']},
#  'segment_type': {'model_ids': ['segment_type_model'],
#   'labels': ['text', 'image', 'table']},
#  'is_truncated': {'model_ids': ['truncation_model'],
#   'labels': ['is_truncated', 'is_not_truncated']},
#  'is_occluded': {'model_ids': ['occlusion_model'],
#   'labels': ['is_occluded', 'is_not_occluded']},
#  'text_segment_boundary_test': {'model_ids': ['test_annotator_1',
#    'test_annotator_2'],
#   'labels': ['xmin', 'ymin', 'xmax', 'ymax']},
#  'text_segment_label': {'model_ids': ['text_segment_label_clf1'],
#   'labels': ['sender', 'receiver', 'footer', 'header']}}

# %% [markdown]
# ## Mocking the model
# To simulate the model, annotated xml files are loaded. The annotations are read from xml and stored in the document data structure. This data structure can be returned to the API to store the page segment annotations.

# %%
# Boundary boxes loaded from xml
def create_segments_from_xml(document_id):
    annotated_pages = []
    with open(document_id[:len(document_id)-4]+".xml", 'r', encoding='utf-8') as fp:
        xml = fp.read()
    document_id = "dd459a615a1fb4da9b46d5da6f9eda88"
    root = ET.fromstring(xml)
    for page_ele in root.findall("page1"):
        annotated_pages.append((document_id,page_ele))
    
    for page_number, annotated_page in enumerate(annotated_pages):
        segment_annotations = []
        _, page_ele = annotated_page
        for segment_ele in page_ele.findall("object"):
            segment_label_text = segment_ele.find("SegmentLabel").text
            segment_id = segment_ele.find("id").text
            if segment_ele.find("truncated").text == '0':
                truncated = 0.0
            else:
                truncated = 1.0
            if segment_ele.find("occluded").text == '0':
                occluded = 0.0
            else:
                occluded = 1.0
            bounding_box = segment_ele.find("bndbox")
            xmin = bounding_box.find("xmin").text
            ymin = bounding_box.find("ymin").text
            xmax = bounding_box.find("xmax").text
            ymax = bounding_box.find("ymax").text
            
            segment = {
                "segment_id": segment_id,
                "child_segments": [],
                "annotation_groups":[
                    {
                        "group_id":0,
                        "importance_score":None,
                        "annotation_type":ANNOTATION_BOUNDING_BOX[0],
                        "annotations":[{
                            "annotation_id":segment_id,
                            "annotator_id":ANNOTATION_BOUNDING_BOX[1],
                            "annotator_type":ANNOTATOR_TYPE,
                            "annotation_vector":[xmin,ymin,xmax,ymax]
                        }]
                    },
                    {
                        "group_id":1,
                        "importance_score":None,
                        "annotation_type":ANNOTATION_SEGMENT_TYPE[0],
                        "annotations":[{
                            "annotation_id":segment_id,
                            "annotator_id":ANNOTATION_SEGMENT_TYPE[1],
                            "annotator_type":ANNOTATOR_TYPE,
                            "annotation_vector":get_annotation_vector(ANNOTATION_SEGMENT_TYPE[0], segment_label_text)
                        }]
                    },
                    {
                        "group_id":2,
                        "importance_score":None,
                        "annotation_type":ANNOTATION_TRUNCATION[0],
                        "annotations":[{
                            "annotation_id":segment_id,
                            "annotator_id":ANNOTATION_TRUNCATION[1],
                            "annotator_type":ANNOTATOR_TYPE,
                            "annotation_vector":[truncated, 1.0 - truncated]
                        }]
                    },
                    {
                        "group_id":3,
                        "importance_score":None,
                        "annotation_type":ANNOTATION_OCCLUSION[0],
                        "annotations":[{
                            "annotation_id":segment_id,
                            "annotator_id":ANNOTATION_OCCLUSION[1],
                            "annotator_type":ANNOTATOR_TYPE,
                            "annotation_vector":[occluded, 1.0 - occluded]
                        }]
                    },
                ]
            }
            segment_annotations.append(segment)
        pages = document_dict[document_id]["pages"]
        pages[page_number]["segments"] = segment_annotations

def get_annotation_vector(annotation_type, label_text):
    # do not use if list of labels is large
    # or label probabilities are provided by the model
    labels = annotation_types[annotation_type]["labels"]
    idx = labels.index(label_text)
    return [1.0 if i == idx else 0.0 for i in range(len(labels))]
    

for document_id in DOCUMENT_NAMES[:1]:
    create_segments_from_xml(document_id)

# all annotations for one page
document_dict[DOCUMENT_NAMES[0]]
# Out:
# {'document_id': 'testdata/3ZCCCW.pdf',
#  'importance_score': 9.4,
#  'document_label': {'group_id': 0,
#   'importance_score': -1,
#   'annotation_type': 'document_label',
#   'annotations': []},
#  'pages': [{'page_number': '0',
#    'page_label': {'group_id': 0,
#     'importance_score': -1,
#     'annotation_type': 'page_label',
#     'annotations': []},
#    'segments': [{'segment_id': 'r0',
#      'child_segments': [],
#      'annotation_groups': [{'group_id': 0,
#        'importance_score': None,
#        'annotation_type': 'segment_boundary',
#        'annotations': [{'annotation_id': 'r0',
#          'annotator_id': 'segment_detection_model',
#          'annotator_type': 'model',
#          'annotation_vector': ['0.0611 ', '0.4016 ', '0.9196 ', '0.4124 ']}]},
#       {'group_id': 1,
#        'importance_score': None,
#        'annotation_type': 'segment_type',
#        'annotations': [{'annotation_id': 'r0',
#          'annotator_id': 'segment_type_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0, 0.0]}]},
#       {'group_id': 2,
#        'importance_score': None,
#        'annotation_type': 'is_truncated',
#        'annotations': [{'annotation_id': 'r0',
#          'annotator_id': 'truncation_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]},
#       {'group_id': 3,
#        'importance_score': None,
#        'annotation_type': 'is_occluded',
#        'annotations': [{'annotation_id': 'r0',
#          'annotator_id': 'occlusion_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]}]},
#     {'segment_id': 'r1',
#      'child_segments': [],
#      'annotation_groups': [{'group_id': 0,
#        'importance_score': None,
#        'annotation_type': 'segment_boundary',
#        'annotations': [{'annotation_id': 'r1',
#          'annotator_id': 'segment_detection_model',
#          'annotator_type': 'model',
#          'annotation_vector': ['0.0611 ', '0.3823 ', '0.9293 ', '0.3943 ']}]},
#       {'group_id': 1,
#        'importance_score': None,
#        'annotation_type': 'segment_type',
#        'annotations': [{'annotation_id': 'r1',
#          'annotator_id': 'segment_type_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0, 0.0]}]},
#       {'group_id': 2,
#        'importance_score': None,
#        'annotation_type': 'is_truncated',
#        'annotations': [{'annotation_id': 'r1',
#          'annotator_id': 'truncation_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]},
#       {'group_id': 3,
#        'importance_score': None,
#        'annotation_type': 'is_occluded',
#        'annotations': [{'annotation_id': 'r1',
#          'annotator_id': 'occlusion_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]}]},
#     {'segment_id': 'r2',
#      'child_segments': [],
#      'annotation_groups': [{'group_id': 0,
#        'importance_score': None,
#        'annotation_type': 'segment_boundary',
#        'annotations': [{'annotation_id': 'r2',
#          'annotator_id': 'segment_detection_model',
#          'annotator_type': 'model',
#          'annotation_vector': ['0.6572 ', '0.0590 ', '0.8960 ', '0.2299 ']}]},
#       {'group_id': 1,
#        'importance_score': None,
#        'annotation_type': 'segment_type',
#        'annotations': [{'annotation_id': 'r2',
#          'annotator_id': 'segment_type_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0, 0.0]}]},
#       {'group_id': 2,
#        'importance_score': None,
#        'annotation_type': 'is_truncated',
#        'annotations': [{'annotation_id': 'r2',
#          'annotator_id': 'truncation_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]},
#       {'group_id': 3,
#        'importance_score': None,
#        'annotation_type': 'is_occluded',
#        'annotations': [{'annotation_id': 'r2',
#          'annotator_id': 'occlusion_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]}]},
#     {'segment_id': 'r3',
#      'child_segments': [],
#      'annotation_groups': [{'group_id': 0,
#        'importance_score': None,
#        'annotation_type': 'segment_boundary',
#        'annotations': [{'annotation_id': 'r3',
#          'annotator_id': 'segment_detection_model',
#          'annotator_type': 'model',
#          'annotation_vector': ['0.8482 ', '0.9634 ', '0.9281 ', '0.9793 ']}]},
#       {'group_id': 1,
#        'importance_score': None,
#        'annotation_type': 'segment_type',
#        'annotations': [{'annotation_id': 'r3',
#          'annotator_id': 'segment_type_model',
#          'annotator_type': 'model',
#          'annotation_vector': [1.0, 0.0, 0.0]}]},
#       {'group_id': 2,
#        'importance_score': None,
#        'annotation_type': 'is_truncated',
#        'annotations': [{'annotation_id': 'r3',
#          'annotator_id': 'truncation_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]},
#       {'group_id': 3,
#        'importance_score': None,
#        'annotation_type': 'is_occluded',
#        'annotations': [{'annotation_id': 'r3',
#          'annotator_id': 'occlusion_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]}]},
#     {'segment_id': 'r4',
#      'child_segments': [],
#      'annotation_groups': [{'group_id': 0,
#        'importance_score': None,
#        'annotation_type': 'segment_boundary',
#        'annotations': [{'annotation_id': 'r4',
#          'annotator_id': 'segment_detection_model',
#          'annotator_type': 'model',
#          'annotation_vector': ['0.0514 ', '0.9634 ', '0.1294 ', '0.9793 ']}]},
#       {'group_id': 1,
#        'importance_score': None,
#        'annotation_type': 'segment_type',
#        'annotations': [{'annotation_id': 'r4',
#          'annotator_id': 'segment_type_model',
#          'annotator_type': 'model',
#          'annotation_vector': [1.0, 0.0, 0.0]}]},
#       {'group_id': 2,
#        'importance_score': None,
#        'annotation_type': 'is_truncated',
#        'annotations': [{'annotation_id': 'r4',
#          'annotator_id': 'truncation_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]},
#       {'group_id': 3,
#        'importance_score': None,
#        'annotation_type': 'is_occluded',
#        'annotations': [{'annotation_id': 'r4',
#          'annotator_id': 'occlusion_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]}]},
#     {'segment_id': 'r5',
#      'child_segments': [],
#      'annotation_groups': [{'group_id': 0,
#        'importance_score': None,
#        'annotation_type': 'segment_boundary',
#        'annotations': [{'annotation_id': 'r5',
#          'annotator_id': 'segment_detection_model',
#          'annotator_type': 'model',
#          'annotation_vector': ['0.7358 ', '0.9384 ', '0.9305 ', '0.9630 ']}]},
#       {'group_id': 1,
#        'importance_score': None,
#        'annotation_type': 'segment_type',
#        'annotations': [{'annotation_id': 'r5',
#          'annotator_id': 'segment_type_model',
#          'annotator_type': 'model',
#          'annotation_vector': [1.0, 0.0, 0.0]}]},
#       {'group_id': 2,
#        'importance_score': None,
#        'annotation_type': 'is_truncated',
#        'annotations': [{'annotation_id': 'r5',
#          'annotator_id': 'truncation_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]},
#       {'group_id': 3,
#        'importance_score': None,
#        'annotation_type': 'is_occluded',
#        'annotations': [{'annotation_id': 'r5',
#          'annotator_id': 'occlusion_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]}]},
#     {'segment_id': 'r6',
#      'child_segments': [],
#      'annotation_groups': [{'group_id': 0,
#        'importance_score': None,
#        'annotation_type': 'segment_boundary',
#        'annotations': [{'annotation_id': 'r6',
#          'annotator_id': 'segment_detection_model',
#          'annotator_type': 'model',
#          'annotation_vector': ['0.0550 ', '0.9105 ', '0.2364 ', '0.9475 ']}]},
#       {'group_id': 1,
#        'importance_score': None,
#        'annotation_type': 'segment_type',
#        'annotations': [{'annotation_id': 'r6',
#          'annotator_id': 'segment_type_model',
#          'annotator_type': 'model',
#          'annotation_vector': [1.0, 0.0, 0.0]}]},
#       {'group_id': 2,
#        'importance_score': None,
#        'annotation_type': 'is_truncated',
#        'annotations': [{'annotation_id': 'r6',
#          'annotator_id': 'truncation_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]},
#       {'group_id': 3,
#        'importance_score': None,
#        'annotation_type': 'is_occluded',
#        'annotations': [{'annotation_id': 'r6',
#          'annotator_id': 'occlusion_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]}]},
#     {'segment_id': 'r7',
#      'child_segments': [],
#      'annotation_groups': [{'group_id': 0,
#        'importance_score': None,
#        'annotation_type': 'segment_boundary',
#        'annotations': [{'annotation_id': 'r7',
#          'annotator_id': 'segment_detection_model',
#          'annotator_type': 'model',
#          'annotation_vector': ['0.7443 ', '0.8898 ', '0.9075 ', '0.9359 ']}]},
#       {'group_id': 1,
#        'importance_score': None,
#        'annotation_type': 'segment_type',
#        'annotations': [{'annotation_id': 'r7',
#          'annotator_id': 'segment_type_model',
#          'annotator_type': 'model',
#          'annotation_vector': [1.0, 0.0, 0.0]}]},
#       {'group_id': 2,
#        'importance_score': None,
#        'annotation_type': 'is_truncated',
#        'annotations': [{'annotation_id': 'r7',
#          'annotator_id': 'truncation_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]},
#       {'group_id': 3,
#        'importance_score': None,
#        'annotation_type': 'is_occluded',
#        'annotations': [{'annotation_id': 'r7',
#          'annotator_id': 'occlusion_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]}]},
#     {'segment_id': 'r8',
#      'child_segments': [],
#      'annotation_groups': [{'group_id': 0,
#        'importance_score': None,
#        'annotation_type': 'segment_boundary',
#        'annotations': [{'annotation_id': 'r8',
#          'annotator_id': 'segment_detection_model',
#          'annotator_type': 'model',
#          'annotation_vector': ['0.7799 ', '0.8360 ', '0.8676 ', '0.8868 ']}]},
#       {'group_id': 1,
#        'importance_score': None,
#        'annotation_type': 'segment_type',
#        'annotations': [{'annotation_id': 'r8',
#          'annotator_id': 'segment_type_model',
#          'annotator_type': 'model',
#          'annotation_vector': [1.0, 0.0, 0.0]}]},
#       {'group_id': 2,
#        'importance_score': None,
#        'annotation_type': 'is_truncated',
#        'annotations': [{'annotation_id': 'r8',
#          'annotator_id': 'truncation_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]},
#       {'group_id': 3,
#        'importance_score': None,
#        'annotation_type': 'is_occluded',
#        'annotations': [{'annotation_id': 'r8',
#          'annotator_id': 'occlusion_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]}]},
#     {'segment_id': 'r9',
#      'child_segments': [],
#      'annotation_groups': [{'group_id': 0,
#        'importance_score': None,
#        'annotation_type': 'segment_boundary',
#        'annotations': [{'annotation_id': 'r9',
#          'annotator_id': 'segment_detection_model',
#          'annotator_type': 'model',
#          'annotation_vector': ['0.2908 ', '0.8330 ', '0.5484 ', '0.9186 ']}]},
#       {'group_id': 1,
#        'importance_score': None,
#        'annotation_type': 'segment_type',
#        'annotations': [{'annotation_id': 'r9',
#          'annotator_id': 'segment_type_model',
#          'annotator_type': 'model',
#          'annotation_vector': [1.0, 0.0, 0.0]}]},
#       {'group_id': 2,
#        'importance_score': None,
#        'annotation_type': 'is_truncated',
#        'annotations': [{'annotation_id': 'r9',
#          'annotator_id': 'truncation_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]},
#       {'group_id': 3,
#        'importance_score': None,
#        'annotation_type': 'is_occluded',
#        'annotations': [{'annotation_id': 'r9',
#          'annotator_id': 'occlusion_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]}]},
#     {'segment_id': 'r10',
#      'child_segments': [],
#      'annotation_groups': [{'group_id': 0,
#        'importance_score': None,
#        'annotation_type': 'segment_boundary',
#        'annotations': [{'annotation_id': 'r10',
#          'annotator_id': 'segment_detection_model',
#          'annotator_type': 'model',
#          'annotation_vector': ['0.0514 ', '0.6005 ', '0.9268 ', '0.6410 ']}]},
#       {'group_id': 1,
#        'importance_score': None,
#        'annotation_type': 'segment_type',
#        'annotations': [{'annotation_id': 'r10',
#          'annotator_id': 'segment_type_model',
#          'annotator_type': 'model',
#          'annotation_vector': [1.0, 0.0, 0.0]}]},
#       {'group_id': 2,
#        'importance_score': None,
#        'annotation_type': 'is_truncated',
#        'annotations': [{'annotation_id': 'r10',
#          'annotator_id': 'truncation_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]},
#       {'group_id': 3,
#        'importance_score': None,
#        'annotation_type': 'is_occluded',
#        'annotations': [{'annotation_id': 'r10',
#          'annotator_id': 'occlusion_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]}]},
#     {'segment_id': 'r11',
#      'child_segments': [],
#      'annotation_groups': [{'group_id': 0,
#        'importance_score': None,
#        'annotation_type': 'segment_boundary',
#        'annotations': [{'annotation_id': 'r11',
#          'annotator_id': 'segment_detection_model',
#          'annotator_type': 'model',
#          'annotation_vector': ['0.0550 ', '0.5837 ', '0.7545 ', '0.6005 ']}]},
#       {'group_id': 1,
#        'importance_score': None,
#        'annotation_type': 'segment_type',
#        'annotations': [{'annotation_id': 'r11',
#          'annotator_id': 'segment_type_model',
#          'annotator_type': 'model',
#          'annotation_vector': [1.0, 0.0, 0.0]}]},
#       {'group_id': 2,
#        'importance_score': None,
#        'annotation_type': 'is_truncated',
#        'annotations': [{'annotation_id': 'r11',
#          'annotator_id': 'truncation_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]},
#       {'group_id': 3,
#        'importance_score': None,
#        'annotation_type': 'is_occluded',
#        'annotations': [{'annotation_id': 'r11',
#          'annotator_id': 'occlusion_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]}]},
#     {'segment_id': 'r12',
#      'child_segments': [],
#      'annotation_groups': [{'group_id': 0,
#        'importance_score': None,
#        'annotation_type': 'segment_boundary',
#        'annotations': [{'annotation_id': 'r12',
#          'annotator_id': 'segment_detection_model',
#          'annotator_type': 'model',
#          'annotation_vector': ['0.0502 ', '0.4731 ', '0.9383 ', '0.5824 ']}]},
#       {'group_id': 1,
#        'importance_score': None,
#        'annotation_type': 'segment_type',
#        'annotations': [{'annotation_id': 'r12',
#          'annotator_id': 'segment_type_model',
#          'annotator_type': 'model',
#          'annotation_vector': [1.0, 0.0, 0.0]}]},
#       {'group_id': 2,
#        'importance_score': None,
#        'annotation_type': 'is_truncated',
#        'annotations': [{'annotation_id': 'r12',
#          'annotator_id': 'truncation_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]},
#       {'group_id': 3,
#        'importance_score': None,
#        'annotation_type': 'is_occluded',
#        'annotations': [{'annotation_id': 'r12',
#          'annotator_id': 'occlusion_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]}]},
#     {'segment_id': 'r13',
#      'child_segments': [],
#      'annotation_groups': [{'group_id': 0,
#        'importance_score': None,
#        'annotation_type': 'segment_boundary',
#        'annotations': [{'annotation_id': 'r13',
#          'annotator_id': 'segment_detection_model',
#          'annotator_type': 'model',
#          'annotation_vector': ['0.4843 ', '0.4111 ', '0.5695 ', '0.4275 ']}]},
#       {'group_id': 1,
#        'importance_score': None,
#        'annotation_type': 'segment_type',
#        'annotations': [{'annotation_id': 'r13',
#          'annotator_id': 'segment_type_model',
#          'annotator_type': 'model',
#          'annotation_vector': [1.0, 0.0, 0.0]}]},
#       {'group_id': 2,
#        'importance_score': None,
#        'annotation_type': 'is_truncated',
#        'annotations': [{'annotation_id': 'r13',
#          'annotator_id': 'truncation_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]},
#       {'group_id': 3,
#        'importance_score': None,
#        'annotation_type': 'is_occluded',
#        'annotations': [{'annotation_id': 'r13',
#          'annotator_id': 'occlusion_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]}]},
#     {'segment_id': 'r14',
#      'child_segments': [],
#      'annotation_groups': [{'group_id': 0,
#        'importance_score': None,
#        'annotation_type': 'segment_boundary',
#        'annotations': [{'annotation_id': 'r14',
#          'annotator_id': 'segment_detection_model',
#          'annotator_type': 'model',
#          'annotation_vector': ['0.3410 ', '0.4102 ', '0.4389 ', '0.4666 ']}]},
#       {'group_id': 1,
#        'importance_score': None,
#        'annotation_type': 'segment_type',
#        'annotations': [{'annotation_id': 'r14',
#          'annotator_id': 'segment_type_model',
#          'annotator_type': 'model',
#          'annotation_vector': [1.0, 0.0, 0.0]}]},
#       {'group_id': 2,
#        'importance_score': None,
#        'annotation_type': 'is_truncated',
#        'annotations': [{'annotation_id': 'r14',
#          'annotator_id': 'truncation_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]},
#       {'group_id': 3,
#        'importance_score': None,
#        'annotation_type': 'is_occluded',
#        'annotations': [{'annotation_id': 'r14',
#          'annotator_id': 'occlusion_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]}]},
#     {'segment_id': 'r15',
#      'child_segments': [],
#      'annotation_groups': [{'group_id': 0,
#        'importance_score': None,
#        'annotation_type': 'segment_boundary',
#        'annotations': [{'annotation_id': 'r15',
#          'annotator_id': 'segment_detection_model',
#          'annotator_type': 'model',
#          'annotation_vector': ['0.2805 ', '0.4102 ', '0.3386 ', '0.4666 ']}]},
#       {'group_id': 1,
#        'importance_score': None,
#        'annotation_type': 'segment_type',
#        'annotations': [{'annotation_id': 'r15',
#          'annotator_id': 'segment_type_model',
#          'annotator_type': 'model',
#          'annotation_vector': [1.0, 0.0, 0.0]}]},
#       {'group_id': 2,
#        'importance_score': None,
#        'annotation_type': 'is_truncated',
#        'annotations': [{'annotation_id': 'r15',
#          'annotator_id': 'truncation_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]},
#       {'group_id': 3,
#        'importance_score': None,
#        'annotation_type': 'is_occluded',
#        'annotations': [{'annotation_id': 'r15',
#          'annotator_id': 'occlusion_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]}]},
#     {'segment_id': 'r16',
#      'child_segments': [],
#      'annotation_groups': [{'group_id': 0,
#        'importance_score': None,
#        'annotation_type': 'segment_boundary',
#        'annotations': [{'annotation_id': 'r16',
#          'annotator_id': 'segment_detection_model',
#          'annotator_type': 'model',
#          'annotation_vector': ['0.0514 ', '0.4102 ', '0.1638 ', '0.4692 ']}]},
#       {'group_id': 1,
#        'importance_score': None,
#        'annotation_type': 'segment_type',
#        'annotations': [{'annotation_id': 'r16',
#          'annotator_id': 'segment_type_model',
#          'annotator_type': 'model',
#          'annotation_vector': [1.0, 0.0, 0.0]}]},
#       {'group_id': 2,
#        'importance_score': None,
#        'annotation_type': 'is_truncated',
#        'annotations': [{'annotation_id': 'r16',
#          'annotator_id': 'truncation_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]},
#       {'group_id': 3,
#        'importance_score': None,
#        'annotation_type': 'is_occluded',
#        'annotations': [{'annotation_id': 'r16',
#          'annotator_id': 'occlusion_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]}]},
#     {'segment_id': 'r17',
#      'child_segments': [],
#      'annotation_groups': [{'group_id': 0,
#        'importance_score': None,
#        'annotation_type': 'segment_boundary',
#        'annotations': [{'annotation_id': 'r17',
#          'annotator_id': 'segment_detection_model',
#          'annotator_type': 'model',
#          'annotation_vector': ['0.0514 ', '0.3285 ', '0.5756 ', '0.3698 ']}]},
#       {'group_id': 1,
#        'importance_score': None,
#        'annotation_type': 'segment_type',
#        'annotations': [{'annotation_id': 'r17',
#          'annotator_id': 'segment_type_model',
#          'annotator_type': 'model',
#          'annotation_vector': [1.0, 0.0, 0.0]}]},
#       {'group_id': 2,
#        'importance_score': None,
#        'annotation_type': 'is_truncated',
#        'annotations': [{'annotation_id': 'r17',
#          'annotator_id': 'truncation_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]},
#       {'group_id': 3,
#        'importance_score': None,
#        'annotation_type': 'is_occluded',
#        'annotations': [{'annotation_id': 'r17',
#          'annotator_id': 'occlusion_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]}]},
#     {'segment_id': 'r18',
#      'child_segments': [],
#      'annotation_groups': [{'group_id': 0,
#        'importance_score': None,
#        'annotation_type': 'segment_boundary',
#        'annotations': [{'annotation_id': 'r18',
#          'annotator_id': 'segment_detection_model',
#          'annotator_type': 'model',
#          'annotation_vector': ['0.8356 ', '0.3229 ', '0.9305 ', '0.3405 ']}]},
#       {'group_id': 1,
#        'importance_score': None,
#        'annotation_type': 'segment_type',
#        'annotations': [{'annotation_id': 'r18',
#          'annotator_id': 'segment_type_model',
#          'annotator_type': 'model',
#          'annotation_vector': [1.0, 0.0, 0.0]}]},
#       {'group_id': 2,
#        'importance_score': None,
#        'annotation_type': 'is_truncated',
#        'annotations': [{'annotation_id': 'r18',
#          'annotator_id': 'truncation_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]},
#       {'group_id': 3,
#        'importance_score': None,
#        'annotation_type': 'is_occluded',
#        'annotations': [{'annotation_id': 'r18',
#          'annotator_id': 'occlusion_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]}]},
#     {'segment_id': 'r19',
#      'child_segments': [],
#      'annotation_groups': [{'group_id': 0,
#        'importance_score': None,
#        'annotation_type': 'segment_boundary',
#        'annotations': [{'annotation_id': 'r19',
#          'annotator_id': 'segment_detection_model',
#          'annotator_type': 'model',
#          'annotation_vector': ['0.5979 ', '0.3091 ', '0.7467 ', '0.3431 ']}]},
#       {'group_id': 1,
#        'importance_score': None,
#        'annotation_type': 'segment_type',
#        'annotations': [{'annotation_id': 'r19',
#          'annotator_id': 'segment_type_model',
#          'annotator_type': 'model',
#          'annotation_vector': [1.0, 0.0, 0.0]}]},
#       {'group_id': 2,
#        'importance_score': None,
#        'annotation_type': 'is_truncated',
#        'annotations': [{'annotation_id': 'r19',
#          'annotator_id': 'truncation_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]},
#       {'group_id': 3,
#        'importance_score': None,
#        'annotation_type': 'is_occluded',
#        'annotations': [{'annotation_id': 'r19',
#          'annotator_id': 'occlusion_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]}]},
#     {'segment_id': 'r20',
#      'child_segments': [],
#      'annotation_groups': [{'group_id': 0,
#        'importance_score': None,
#        'annotation_type': 'segment_boundary',
#        'annotations': [{'annotation_id': 'r20',
#          'annotator_id': 'segment_detection_model',
#          'annotator_type': 'model',
#          'annotation_vector': ['0.2195 ', '0.2996 ', '0.2836 ', '0.3259 ']}]},
#       {'group_id': 1,
#        'importance_score': None,
#        'annotation_type': 'segment_type',
#        'annotations': [{'annotation_id': 'r20',
#          'annotator_id': 'segment_type_model',
#          'annotator_type': 'model',
#          'annotation_vector': [1.0, 0.0, 0.0]}]},
#       {'group_id': 2,
#        'importance_score': None,
#        'annotation_type': 'is_truncated',
#        'annotations': [{'annotation_id': 'r20',
#          'annotator_id': 'truncation_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]},
#       {'group_id': 3,
#        'importance_score': None,
#        'annotation_type': 'is_occluded',
#        'annotations': [{'annotation_id': 'r20',
#          'annotator_id': 'occlusion_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]}]},
#     {'segment_id': 'r21',
#      'child_segments': [],
#      'annotation_groups': [{'group_id': 0,
#        'importance_score': None,
#        'annotation_type': 'segment_boundary',
#        'annotations': [{'annotation_id': 'r21',
#          'annotator_id': 'segment_detection_model',
#          'annotator_type': 'model',
#          'annotation_vector': ['0.2896 ', '0.2992 ', '0.5006 ', '0.3259 ']}]},
#       {'group_id': 1,
#        'importance_score': None,
#        'annotation_type': 'segment_type',
#        'annotations': [{'annotation_id': 'r21',
#          'annotator_id': 'segment_type_model',
#          'annotator_type': 'model',
#          'annotation_vector': [1.0, 0.0, 0.0]}]},
#       {'group_id': 2,
#        'importance_score': None,
#        'annotation_type': 'is_truncated',
#        'annotations': [{'annotation_id': 'r21',
#          'annotator_id': 'truncation_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]},
#       {'group_id': 3,
#        'importance_score': None,
#        'annotation_type': 'is_occluded',
#        'annotations': [{'annotation_id': 'r21',
#          'annotator_id': 'occlusion_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]}]},
#     {'segment_id': 'r22',
#      'child_segments': [],
#      'annotation_groups': [{'group_id': 0,
#        'importance_score': None,
#        'annotation_type': 'segment_boundary',
#        'annotations': [{'annotation_id': 'r22',
#          'annotator_id': 'segment_detection_model',
#          'annotator_type': 'model',
#          'annotation_vector': ['0.6953 ', '0.2656 ', '0.7830 ', '0.2811 ']}]},
#       {'group_id': 1,
#        'importance_score': None,
#        'annotation_type': 'segment_type',
#        'annotations': [{'annotation_id': 'r22',
#          'annotator_id': 'segment_type_model',
#          'annotator_type': 'model',
#          'annotation_vector': [1.0, 0.0, 0.0]}]},
#       {'group_id': 2,
#        'importance_score': None,
#        'annotation_type': 'is_truncated',
#        'annotations': [{'annotation_id': 'r22',
#          'annotator_id': 'truncation_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]},
#       {'group_id': 3,
#        'importance_score': None,
#        'annotation_type': 'is_occluded',
#        'annotations': [{'annotation_id': 'r22',
#          'annotator_id': 'occlusion_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]}]},
#     {'segment_id': 'r23',
#      'child_segments': [],
#      'annotation_groups': [{'group_id': 0,
#        'importance_score': None,
#        'annotation_type': 'segment_boundary',
#        'annotations': [{'annotation_id': 'r23',
#          'annotator_id': 'segment_detection_model',
#          'annotator_type': 'model',
#          'annotation_vector': ['0.7902 ', '0.2523 ', '0.9293 ', '0.3104 ']}]},
#       {'group_id': 1,
#        'importance_score': None,
#        'annotation_type': 'segment_type',
#        'annotations': [{'annotation_id': 'r23',
#          'annotator_id': 'segment_type_model',
#          'annotator_type': 'model',
#          'annotation_vector': [1.0, 0.0, 0.0]}]},
#       {'group_id': 2,
#        'importance_score': None,
#        'annotation_type': 'is_truncated',
#        'annotations': [{'annotation_id': 'r23',
#          'annotator_id': 'truncation_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]},
#       {'group_id': 3,
#        'importance_score': None,
#        'annotation_type': 'is_occluded',
#        'annotations': [{'annotation_id': 'r23',
#          'annotator_id': 'occlusion_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]}]},
#     {'segment_id': 'r24',
#      'child_segments': [],
#      'annotation_groups': [{'group_id': 0,
#        'importance_score': None,
#        'annotation_type': 'segment_boundary',
#        'annotations': [{'annotation_id': 'r24',
#          'annotator_id': 'segment_detection_model',
#          'annotator_type': 'model',
#          'annotation_vector': ['0.5992 ', '0.2441 ', '0.6729 ', '0.2975 ']}]},
#       {'group_id': 1,
#        'importance_score': None,
#        'annotation_type': 'segment_type',
#        'annotations': [{'annotation_id': 'r24',
#          'annotator_id': 'segment_type_model',
#          'annotator_type': 'model',
#          'annotation_vector': [1.0, 0.0, 0.0]}]},
#       {'group_id': 2,
#        'importance_score': None,
#        'annotation_type': 'is_truncated',
#        'annotations': [{'annotation_id': 'r24',
#          'annotator_id': 'truncation_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]},
#       {'group_id': 3,
#        'importance_score': None,
#        'annotation_type': 'is_occluded',
#        'annotations': [{'annotation_id': 'r24',
#          'annotator_id': 'occlusion_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]}]},
#     {'segment_id': 'r25',
#      'child_segments': [],
#      'annotation_groups': [{'group_id': 0,
#        'importance_score': None,
#        'annotation_type': 'segment_boundary',
#        'annotations': [{'annotation_id': 'r25',
#          'annotator_id': 'segment_detection_model',
#          'annotator_type': 'model',
#          'annotation_vector': ['0.4655 ', '0.2385 ', '0.5647 ', '0.2540 ']}]},
#       {'group_id': 1,
#        'importance_score': None,
#        'annotation_type': 'segment_type',
#        'annotations': [{'annotation_id': 'r25',
#          'annotator_id': 'segment_type_model',
#          'annotator_type': 'model',
#          'annotation_vector': [1.0, 0.0, 0.0]}]},
#       {'group_id': 2,
#        'importance_score': None,
#        'annotation_type': 'is_truncated',
#        'annotations': [{'annotation_id': 'r25',
#          'annotator_id': 'truncation_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]},
#       {'group_id': 3,
#        'importance_score': None,
#        'annotation_type': 'is_occluded',
#        'annotations': [{'annotation_id': 'r25',
#          'annotator_id': 'occlusion_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]}]},
#     {'segment_id': 'r26',
#      'child_segments': [],
#      'annotation_groups': [{'group_id': 0,
#        'importance_score': None,
#        'annotation_type': 'segment_boundary',
#        'annotations': [{'annotation_id': 'r26',
#          'annotator_id': 'segment_detection_model',
#          'annotator_type': 'model',
#          'annotation_vector': ['0.3102 ', '0.2385 ', '0.4450 ', '0.2893 ']}]},
#       {'group_id': 1,
#        'importance_score': None,
#        'annotation_type': 'segment_type',
#        'annotations': [{'annotation_id': 'r26',
#          'annotator_id': 'segment_type_model',
#          'annotator_type': 'model',
#          'annotation_vector': [1.0, 0.0, 0.0]}]},
#       {'group_id': 2,
#        'importance_score': None,
#        'annotation_type': 'is_truncated',
#        'annotations': [{'annotation_id': 'r26',
#          'annotator_id': 'truncation_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]},
#       {'group_id': 3,
#        'importance_score': None,
#        'annotation_type': 'is_occluded',
#        'annotations': [{'annotation_id': 'r26',
#          'annotator_id': 'occlusion_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]}]},
#     {'segment_id': 'r27',
#      'child_segments': [],
#      'annotation_groups': [{'group_id': 0,
#        'importance_score': None,
#        'annotation_type': 'segment_boundary',
#        'annotations': [{'annotation_id': 'r27',
#          'annotator_id': 'segment_detection_model',
#          'annotator_type': 'model',
#          'annotation_vector': ['0.2340 ', '0.2385 ', '0.2969 ', '0.2884 ']}]},
#       {'group_id': 1,
#        'importance_score': None,
#        'annotation_type': 'segment_type',
#        'annotations': [{'annotation_id': 'r27',
#          'annotator_id': 'segment_type_model',
#          'annotator_type': 'model',
#          'annotation_vector': [1.0, 0.0, 0.0]}]},
#       {'group_id': 2,
#        'importance_score': None,
#        'annotation_type': 'is_truncated',
#        'annotations': [{'annotation_id': 'r27',
#          'annotator_id': 'truncation_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]},
#       {'group_id': 3,
#        'importance_score': None,
#        'annotation_type': 'is_occluded',
#        'annotations': [{'annotation_id': 'r27',
#          'annotator_id': 'occlusion_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]}]},
#     {'segment_id': 'r28',
#      'child_segments': [],
#      'annotation_groups': [{'group_id': 0,
#        'importance_score': None,
#        'annotation_type': 'segment_boundary',
#        'annotations': [{'annotation_id': 'r28',
#          'annotator_id': 'segment_detection_model',
#          'annotator_type': 'model',
#          'annotation_vector': ['0.0502 ', '0.2208 ', '0.3144 ', '0.3259 ']}]},
#       {'group_id': 1,
#        'importance_score': None,
#        'annotation_type': 'segment_type',
#        'annotations': [{'annotation_id': 'r28',
#          'annotator_id': 'segment_type_model',
#          'annotator_type': 'model',
#          'annotation_vector': [1.0, 0.0, 0.0]}]},
#       {'group_id': 2,
#        'importance_score': None,
#        'annotation_type': 'is_truncated',
#        'annotations': [{'annotation_id': 'r28',
#          'annotator_id': 'truncation_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]},
#       {'group_id': 3,
#        'importance_score': None,
#        'annotation_type': 'is_occluded',
#        'annotations': [{'annotation_id': 'r28',
#          'annotator_id': 'occlusion_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]}]},
#     {'segment_id': 'r29',
#      'child_segments': [],
#      'annotation_groups': [{'group_id': 0,
#        'importance_score': None,
#        'annotation_type': 'segment_boundary',
#        'annotations': [{'annotation_id': 'r29',
#          'annotator_id': 'segment_detection_model',
#          'annotator_type': 'model',
#          'annotation_vector': ['0.0514 ', '0.0908 ', '0.4758 ', '0.2165 ']}]},
#       {'group_id': 1,
#        'importance_score': None,
#        'annotation_type': 'segment_type',
#        'annotations': [{'annotation_id': 'r29',
#          'annotator_id': 'segment_type_model',
#          'annotator_type': 'model',
#          'annotation_vector': [1.0, 0.0, 0.0]}]},
#       {'group_id': 2,
#        'importance_score': None,
#        'annotation_type': 'is_truncated',
#        'annotations': [{'annotation_id': 'r29',
#          'annotator_id': 'truncation_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]},
#       {'group_id': 3,
#        'importance_score': None,
#        'annotation_type': 'is_occluded',
#        'annotations': [{'annotation_id': 'r29',
#          'annotator_id': 'occlusion_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]}]},
#     {'segment_id': 'r30',
#      'child_segments': [],
#      'annotation_groups': [{'group_id': 0,
#        'importance_score': None,
#        'annotation_type': 'segment_boundary',
#        'annotations': [{'annotation_id': 'r30',
#          'annotator_id': 'segment_detection_model',
#          'annotator_type': 'model',
#          'annotation_vector': ['0.6016 ', '0.0740 ', '0.6324 ', '0.1817 ']}]},
#       {'group_id': 1,
#        'importance_score': None,
#        'annotation_type': 'segment_type',
#        'annotations': [{'annotation_id': 'r30',
#          'annotator_id': 'segment_type_model',
#          'annotator_type': 'model',
#          'annotation_vector': [1.0, 0.0, 0.0]}]},
#       {'group_id': 2,
#        'importance_score': None,
#        'annotation_type': 'is_truncated',
#        'annotations': [{'annotation_id': 'r30',
#          'annotator_id': 'truncation_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]},
#       {'group_id': 3,
#        'importance_score': None,
#        'annotation_type': 'is_occluded',
#        'annotations': [{'annotation_id': 'r30',
#          'annotator_id': 'occlusion_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]}]},
#     {'segment_id': 'r31',
#      'child_segments': [],
#      'annotation_groups': [{'group_id': 0,
#        'importance_score': None,
#        'annotation_type': 'segment_boundary',
#        'annotations': [{'annotation_id': 'r31',
#          'annotator_id': 'segment_detection_model',
#          'annotator_type': 'model',
#          'annotation_vector': ['0.3597 ', '0.0452 ', '0.5732 ', '0.0697 ']}]},
#       {'group_id': 1,
#        'importance_score': None,
#        'annotation_type': 'segment_type',
#        'annotations': [{'annotation_id': 'r31',
#          'annotator_id': 'segment_type_model',
#          'annotator_type': 'model',
#          'annotation_vector': [1.0, 0.0, 0.0]}]},
#       {'group_id': 2,
#        'importance_score': None,
#        'annotation_type': 'is_truncated',
#        'annotations': [{'annotation_id': 'r31',
#          'annotator_id': 'truncation_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]},
#       {'group_id': 3,
#        'importance_score': None,
#        'annotation_type': 'is_occluded',
#        'annotations': [{'annotation_id': 'r31',
#          'annotator_id': 'occlusion_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]}]},
#     {'segment_id': 'r32',
#      'child_segments': [],
#      'annotation_groups': [{'group_id': 0,
#        'importance_score': None,
#        'annotation_type': 'segment_boundary',
#        'annotations': [{'annotation_id': 'r32',
#          'annotator_id': 'segment_detection_model',
#          'annotator_type': 'model',
#          'annotation_vector': ['0.0599 ', '0.0379 ', '0.1391 ', '0.0740 ']}]},
#       {'group_id': 1,
#        'importance_score': None,
#        'annotation_type': 'segment_type',
#        'annotations': [{'annotation_id': 'r32',
#          'annotator_id': 'segment_type_model',
#          'annotator_type': 'model',
#          'annotation_vector': [1.0, 0.0, 0.0]}]},
#       {'group_id': 2,
#        'importance_score': None,
#        'annotation_type': 'is_truncated',
#        'annotations': [{'annotation_id': 'r32',
#          'annotator_id': 'truncation_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]},
#       {'group_id': 3,
#        'importance_score': None,
#        'annotation_type': 'is_occluded',
#        'annotations': [{'annotation_id': 'r32',
#          'annotator_id': 'occlusion_model',
#          'annotator_type': 'model',
#          'annotation_vector': [0.0, 1.0]}]}]}]}]}

# %% [markdown]
# # 3. **AP4->AP3:** Additional text classification is performed and added to the segments

# %%
# TODO

# %% [markdown]
# # 4. **AP3->AP2:** Segment annotations are added to the documents in the collection
# Using the page_id_dict data structure, the page segment annotations are saved.

# %%
# Send data to API
data_in = document_dict


url = "http://localhost:5000/add_segment_boundary_annotations_to_page/"
resp = post_json(data_in, url)
print("Saved annotations to db")
# Out:
# Saved annotations to db

# %% [markdown]
# # 5. **AP2 (Active Learning):** Importance score is calculated for each annotation and, based on that, each document

# %%
# TODO: Do in the AL container

# %% [markdown]
# # 6. **AP2 (Active Learning) -> AP2 (Annotation Tool):** Most important documents are selected and passed to the annotation tool
# At the moment implemented so that annotation tool asks for the documents. Might need to be reversed.

# %%
best_docs = []

url = "http://localhost:5000/init_next_most_important/"
get_json(url)

url = "http://localhost:5000/next_most_important/"
document_id, score = json.loads(get_json(url))
print(document_id, score)
best_docs.append(document_id)

url = "http://localhost:5000/next_most_important/"
document_id, score = json.loads(get_json(url))
print(document_id, score)
best_docs.append(document_id)
# Out:
# testdata/3ZCCCW.pdf 9.4
# testdata/01-Anfrage-Musterbrief_1.pdf 5.8

# %%
url = "http://localhost:5000/get_document/" + best_docs[0]
document = json.loads(get_json(url))
pprint(document)
# Out:
# {'document_id': 'testdata/3ZCCCW.pdf',
#  'document_label': {'annotation_type': 'document_label',
#                     'annotations': [],
#                     'group_id': 0,
#                     'importance_score': -1},
#  'importance_score': 9.4,
#  'pages': [{'page_label': {'annotation_type': 'page_label',
#                            'annotations': [],
#                            'group_id': 0,
#                            'importance_score': -1},
#             'page_number': '0',
#             'segments': [{'annotation_groups': [{'annotation_type': 'segment_boundary',
#                                                  'annotations': [{'annotation_id': 'r0',
#                                                                   'annotation_vector': ['0.0611 ',
#                                                                                         '0.4016 ',
#                                                                                         '0.9196 ',
#                                                                                         '0.4124 '],
#                                                                   'annotator_id': 'segment_detection_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 0,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'segment_type',
#                                                  'annotations': [{'annotation_id': 'r0',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0,
#                                                                                         0.0],
#                                                                   'annotator_id': 'segment_type_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 1,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_truncated',
#                                                  'annotations': [{'annotation_id': 'r0',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'truncation_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 2,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_occluded',
#                                                  'annotations': [{'annotation_id': 'r0',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'occlusion_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 3,
#                                                  'importance_score': None}],
#                           'child_segments': [],
#                           'segment_id': 'r0'},
#                          {'annotation_groups': [{'annotation_type': 'segment_boundary',
#                                                  'annotations': [{'annotation_id': 'r1',
#                                                                   'annotation_vector': ['0.0611 ',
#                                                                                         '0.3823 ',
#                                                                                         '0.9293 ',
#                                                                                         '0.3943 '],
#                                                                   'annotator_id': 'segment_detection_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 0,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'segment_type',
#                                                  'annotations': [{'annotation_id': 'r1',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0,
#                                                                                         0.0],
#                                                                   'annotator_id': 'segment_type_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 1,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_truncated',
#                                                  'annotations': [{'annotation_id': 'r1',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'truncation_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 2,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_occluded',
#                                                  'annotations': [{'annotation_id': 'r1',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'occlusion_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 3,
#                                                  'importance_score': None}],
#                           'child_segments': [],
#                           'segment_id': 'r1'},
#                          {'annotation_groups': [{'annotation_type': 'segment_boundary',
#                                                  'annotations': [{'annotation_id': 'r2',
#                                                                   'annotation_vector': ['0.6572 ',
#                                                                                         '0.0590 ',
#                                                                                         '0.8960 ',
#                                                                                         '0.2299 '],
#                                                                   'annotator_id': 'segment_detection_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 0,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'segment_type',
#                                                  'annotations': [{'annotation_id': 'r2',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0,
#                                                                                         0.0],
#                                                                   'annotator_id': 'segment_type_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 1,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_truncated',
#                                                  'annotations': [{'annotation_id': 'r2',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'truncation_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 2,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_occluded',
#                                                  'annotations': [{'annotation_id': 'r2',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'occlusion_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 3,
#                                                  'importance_score': None}],
#                           'child_segments': [],
#                           'segment_id': 'r2'},
#                          {'annotation_groups': [{'annotation_type': 'segment_boundary',
#                                                  'annotations': [{'annotation_id': 'r3',
#                                                                   'annotation_vector': ['0.8482 ',
#                                                                                         '0.9634 ',
#                                                                                         '0.9281 ',
#                                                                                         '0.9793 '],
#                                                                   'annotator_id': 'segment_detection_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 0,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'segment_type',
#                                                  'annotations': [{'annotation_id': 'r3',
#                                                                   'annotation_vector': [1.0,
#                                                                                         0.0,
#                                                                                         0.0],
#                                                                   'annotator_id': 'segment_type_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 1,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_truncated',
#                                                  'annotations': [{'annotation_id': 'r3',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'truncation_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 2,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_occluded',
#                                                  'annotations': [{'annotation_id': 'r3',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'occlusion_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 3,
#                                                  'importance_score': None}],
#                           'child_segments': [],
#                           'segment_id': 'r3'},
#                          {'annotation_groups': [{'annotation_type': 'segment_boundary',
#                                                  'annotations': [{'annotation_id': 'r4',
#                                                                   'annotation_vector': ['0.0514 ',
#                                                                                         '0.9634 ',
#                                                                                         '0.1294 ',
#                                                                                         '0.9793 '],
#                                                                   'annotator_id': 'segment_detection_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 0,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'segment_type',
#                                                  'annotations': [{'annotation_id': 'r4',
#                                                                   'annotation_vector': [1.0,
#                                                                                         0.0,
#                                                                                         0.0],
#                                                                   'annotator_id': 'segment_type_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 1,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_truncated',
#                                                  'annotations': [{'annotation_id': 'r4',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'truncation_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 2,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_occluded',
#                                                  'annotations': [{'annotation_id': 'r4',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'occlusion_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 3,
#                                                  'importance_score': None}],
#                           'child_segments': [],
#                           'segment_id': 'r4'},
#                          {'annotation_groups': [{'annotation_type': 'segment_boundary',
#                                                  'annotations': [{'annotation_id': 'r5',
#                                                                   'annotation_vector': ['0.7358 ',
#                                                                                         '0.9384 ',
#                                                                                         '0.9305 ',
#                                                                                         '0.9630 '],
#                                                                   'annotator_id': 'segment_detection_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 0,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'segment_type',
#                                                  'annotations': [{'annotation_id': 'r5',
#                                                                   'annotation_vector': [1.0,
#                                                                                         0.0,
#                                                                                         0.0],
#                                                                   'annotator_id': 'segment_type_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 1,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_truncated',
#                                                  'annotations': [{'annotation_id': 'r5',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'truncation_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 2,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_occluded',
#                                                  'annotations': [{'annotation_id': 'r5',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'occlusion_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 3,
#                                                  'importance_score': None}],
#                           'child_segments': [],
#                           'segment_id': 'r5'},
#                          {'annotation_groups': [{'annotation_type': 'segment_boundary',
#                                                  'annotations': [{'annotation_id': 'r6',
#                                                                   'annotation_vector': ['0.0550 ',
#                                                                                         '0.9105 ',
#                                                                                         '0.2364 ',
#                                                                                         '0.9475 '],
#                                                                   'annotator_id': 'segment_detection_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 0,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'segment_type',
#                                                  'annotations': [{'annotation_id': 'r6',
#                                                                   'annotation_vector': [1.0,
#                                                                                         0.0,
#                                                                                         0.0],
#                                                                   'annotator_id': 'segment_type_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 1,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_truncated',
#                                                  'annotations': [{'annotation_id': 'r6',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'truncation_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 2,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_occluded',
#                                                  'annotations': [{'annotation_id': 'r6',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'occlusion_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 3,
#                                                  'importance_score': None}],
#                           'child_segments': [],
#                           'segment_id': 'r6'},
#                          {'annotation_groups': [{'annotation_type': 'segment_boundary',
#                                                  'annotations': [{'annotation_id': 'r7',
#                                                                   'annotation_vector': ['0.7443 ',
#                                                                                         '0.8898 ',
#                                                                                         '0.9075 ',
#                                                                                         '0.9359 '],
#                                                                   'annotator_id': 'segment_detection_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 0,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'segment_type',
#                                                  'annotations': [{'annotation_id': 'r7',
#                                                                   'annotation_vector': [1.0,
#                                                                                         0.0,
#                                                                                         0.0],
#                                                                   'annotator_id': 'segment_type_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 1,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_truncated',
#                                                  'annotations': [{'annotation_id': 'r7',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'truncation_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 2,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_occluded',
#                                                  'annotations': [{'annotation_id': 'r7',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'occlusion_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 3,
#                                                  'importance_score': None}],
#                           'child_segments': [],
#                           'segment_id': 'r7'},
#                          {'annotation_groups': [{'annotation_type': 'segment_boundary',
#                                                  'annotations': [{'annotation_id': 'r8',
#                                                                   'annotation_vector': ['0.7799 ',
#                                                                                         '0.8360 ',
#                                                                                         '0.8676 ',
#                                                                                         '0.8868 '],
#                                                                   'annotator_id': 'segment_detection_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 0,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'segment_type',
#                                                  'annotations': [{'annotation_id': 'r8',
#                                                                   'annotation_vector': [1.0,
#                                                                                         0.0,
#                                                                                         0.0],
#                                                                   'annotator_id': 'segment_type_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 1,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_truncated',
#                                                  'annotations': [{'annotation_id': 'r8',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'truncation_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 2,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_occluded',
#                                                  'annotations': [{'annotation_id': 'r8',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'occlusion_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 3,
#                                                  'importance_score': None}],
#                           'child_segments': [],
#                           'segment_id': 'r8'},
#                          {'annotation_groups': [{'annotation_type': 'segment_boundary',
#                                                  'annotations': [{'annotation_id': 'r9',
#                                                                   'annotation_vector': ['0.2908 ',
#                                                                                         '0.8330 ',
#                                                                                         '0.5484 ',
#                                                                                         '0.9186 '],
#                                                                   'annotator_id': 'segment_detection_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 0,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'segment_type',
#                                                  'annotations': [{'annotation_id': 'r9',
#                                                                   'annotation_vector': [1.0,
#                                                                                         0.0,
#                                                                                         0.0],
#                                                                   'annotator_id': 'segment_type_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 1,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_truncated',
#                                                  'annotations': [{'annotation_id': 'r9',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'truncation_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 2,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_occluded',
#                                                  'annotations': [{'annotation_id': 'r9',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'occlusion_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 3,
#                                                  'importance_score': None}],
#                           'child_segments': [],
#                           'segment_id': 'r9'},
#                          {'annotation_groups': [{'annotation_type': 'segment_boundary',
#                                                  'annotations': [{'annotation_id': 'r10',
#                                                                   'annotation_vector': ['0.0514 ',
#                                                                                         '0.6005 ',
#                                                                                         '0.9268 ',
#                                                                                         '0.6410 '],
#                                                                   'annotator_id': 'segment_detection_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 0,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'segment_type',
#                                                  'annotations': [{'annotation_id': 'r10',
#                                                                   'annotation_vector': [1.0,
#                                                                                         0.0,
#                                                                                         0.0],
#                                                                   'annotator_id': 'segment_type_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 1,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_truncated',
#                                                  'annotations': [{'annotation_id': 'r10',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'truncation_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 2,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_occluded',
#                                                  'annotations': [{'annotation_id': 'r10',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'occlusion_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 3,
#                                                  'importance_score': None}],
#                           'child_segments': [],
#                           'segment_id': 'r10'},
#                          {'annotation_groups': [{'annotation_type': 'segment_boundary',
#                                                  'annotations': [{'annotation_id': 'r11',
#                                                                   'annotation_vector': ['0.0550 ',
#                                                                                         '0.5837 ',
#                                                                                         '0.7545 ',
#                                                                                         '0.6005 '],
#                                                                   'annotator_id': 'segment_detection_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 0,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'segment_type',
#                                                  'annotations': [{'annotation_id': 'r11',
#                                                                   'annotation_vector': [1.0,
#                                                                                         0.0,
#                                                                                         0.0],
#                                                                   'annotator_id': 'segment_type_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 1,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_truncated',
#                                                  'annotations': [{'annotation_id': 'r11',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'truncation_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 2,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_occluded',
#                                                  'annotations': [{'annotation_id': 'r11',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'occlusion_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 3,
#                                                  'importance_score': None}],
#                           'child_segments': [],
#                           'segment_id': 'r11'},
#                          {'annotation_groups': [{'annotation_type': 'segment_boundary',
#                                                  'annotations': [{'annotation_id': 'r12',
#                                                                   'annotation_vector': ['0.0502 ',
#                                                                                         '0.4731 ',
#                                                                                         '0.9383 ',
#                                                                                         '0.5824 '],
#                                                                   'annotator_id': 'segment_detection_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 0,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'segment_type',
#                                                  'annotations': [{'annotation_id': 'r12',
#                                                                   'annotation_vector': [1.0,
#                                                                                         0.0,
#                                                                                         0.0],
#                                                                   'annotator_id': 'segment_type_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 1,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_truncated',
#                                                  'annotations': [{'annotation_id': 'r12',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'truncation_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 2,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_occluded',
#                                                  'annotations': [{'annotation_id': 'r12',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'occlusion_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 3,
#                                                  'importance_score': None}],
#                           'child_segments': [],
#                           'segment_id': 'r12'},
#                          {'annotation_groups': [{'annotation_type': 'segment_boundary',
#                                                  'annotations': [{'annotation_id': 'r13',
#                                                                   'annotation_vector': ['0.4843 ',
#                                                                                         '0.4111 ',
#                                                                                         '0.5695 ',
#                                                                                         '0.4275 '],
#                                                                   'annotator_id': 'segment_detection_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 0,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'segment_type',
#                                                  'annotations': [{'annotation_id': 'r13',
#                                                                   'annotation_vector': [1.0,
#                                                                                         0.0,
#                                                                                         0.0],
#                                                                   'annotator_id': 'segment_type_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 1,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_truncated',
#                                                  'annotations': [{'annotation_id': 'r13',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'truncation_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 2,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_occluded',
#                                                  'annotations': [{'annotation_id': 'r13',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'occlusion_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 3,
#                                                  'importance_score': None}],
#                           'child_segments': [],
#                           'segment_id': 'r13'},
#                          {'annotation_groups': [{'annotation_type': 'segment_boundary',
#                                                  'annotations': [{'annotation_id': 'r14',
#                                                                   'annotation_vector': ['0.3410 ',
#                                                                                         '0.4102 ',
#                                                                                         '0.4389 ',
#                                                                                         '0.4666 '],
#                                                                   'annotator_id': 'segment_detection_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 0,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'segment_type',
#                                                  'annotations': [{'annotation_id': 'r14',
#                                                                   'annotation_vector': [1.0,
#                                                                                         0.0,
#                                                                                         0.0],
#                                                                   'annotator_id': 'segment_type_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 1,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_truncated',
#                                                  'annotations': [{'annotation_id': 'r14',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'truncation_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 2,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_occluded',
#                                                  'annotations': [{'annotation_id': 'r14',
#                                                                   'annotation_vector': [0.0,
# ...
#                                                  'annotations': [{'annotation_id': 'r28',
#                                                                   'annotation_vector': ['0.0502 ',
#                                                                                         '0.2208 ',
#                                                                                         '0.3144 ',
#                                                                                         '0.3259 '],
#                                                                   'annotator_id': 'segment_detection_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 0,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'segment_type',
#                                                  'annotations': [{'annotation_id': 'r28',
#                                                                   'annotation_vector': [1.0,
#                                                                                         0.0,
#                                                                                         0.0],
#                                                                   'annotator_id': 'segment_type_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 1,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_truncated',
#                                                  'annotations': [{'annotation_id': 'r28',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'truncation_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 2,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_occluded',
#                                                  'annotations': [{'annotation_id': 'r28',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'occlusion_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 3,
#                                                  'importance_score': None}],
#                           'child_segments': [],
#                           'segment_id': 'r28'},
#                          {'annotation_groups': [{'annotation_type': 'segment_boundary',
#                                                  'annotations': [{'annotation_id': 'r29',
#                                                                   'annotation_vector': ['0.0514 ',
#                                                                                         '0.0908 ',
#                                                                                         '0.4758 ',
#                                                                                         '0.2165 '],
#                                                                   'annotator_id': 'segment_detection_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 0,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'segment_type',
#                                                  'annotations': [{'annotation_id': 'r29',
#                                                                   'annotation_vector': [1.0,
#                                                                                         0.0,
#                                                                                         0.0],
#                                                                   'annotator_id': 'segment_type_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 1,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_truncated',
#                                                  'annotations': [{'annotation_id': 'r29',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'truncation_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 2,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_occluded',
#                                                  'annotations': [{'annotation_id': 'r29',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'occlusion_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 3,
#                                                  'importance_score': None}],
#                           'child_segments': [],
#                           'segment_id': 'r29'},
#                          {'annotation_groups': [{'annotation_type': 'segment_boundary',
#                                                  'annotations': [{'annotation_id': 'r30',
#                                                                   'annotation_vector': ['0.6016 ',
#                                                                                         '0.0740 ',
#                                                                                         '0.6324 ',
#                                                                                         '0.1817 '],
#                                                                   'annotator_id': 'segment_detection_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 0,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'segment_type',
#                                                  'annotations': [{'annotation_id': 'r30',
#                                                                   'annotation_vector': [1.0,
#                                                                                         0.0,
#                                                                                         0.0],
#                                                                   'annotator_id': 'segment_type_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 1,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_truncated',
#                                                  'annotations': [{'annotation_id': 'r30',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'truncation_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 2,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_occluded',
#                                                  'annotations': [{'annotation_id': 'r30',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'occlusion_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 3,
#                                                  'importance_score': None}],
#                           'child_segments': [],
#                           'segment_id': 'r30'},
#                          {'annotation_groups': [{'annotation_type': 'segment_boundary',
#                                                  'annotations': [{'annotation_id': 'r31',
#                                                                   'annotation_vector': ['0.3597 ',
#                                                                                         '0.0452 ',
#                                                                                         '0.5732 ',
#                                                                                         '0.0697 '],
#                                                                   'annotator_id': 'segment_detection_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 0,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'segment_type',
#                                                  'annotations': [{'annotation_id': 'r31',
#                                                                   'annotation_vector': [1.0,
#                                                                                         0.0,
#                                                                                         0.0],
#                                                                   'annotator_id': 'segment_type_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 1,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_truncated',
#                                                  'annotations': [{'annotation_id': 'r31',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'truncation_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 2,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_occluded',
#                                                  'annotations': [{'annotation_id': 'r31',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'occlusion_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 3,
#                                                  'importance_score': None}],
#                           'child_segments': [],
#                           'segment_id': 'r31'},
#                          {'annotation_groups': [{'annotation_type': 'segment_boundary',
#                                                  'annotations': [{'annotation_id': 'r32',
#                                                                   'annotation_vector': ['0.0599 ',
#                                                                                         '0.0379 ',
#                                                                                         '0.1391 ',
#                                                                                         '0.0740 '],
#                                                                   'annotator_id': 'segment_detection_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 0,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'segment_type',
#                                                  'annotations': [{'annotation_id': 'r32',
#                                                                   'annotation_vector': [1.0,
#                                                                                         0.0,
#                                                                                         0.0],
#                                                                   'annotator_id': 'segment_type_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 1,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_truncated',
#                                                  'annotations': [{'annotation_id': 'r32',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'truncation_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 2,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_occluded',
#                                                  'annotations': [{'annotation_id': 'r32',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'occlusion_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 3,
#                                                  'importance_score': None}],
#                           'child_segments': [],
#                           'segment_id': 'r32'}]}]}

# %%
url = "http://localhost:5000/get_document/" + best_docs[1]
document = json.loads(get_json(url))
pprint(document)
# Out:
# {'document_id': 'testdata/01-Anfrage-Musterbrief_1.pdf',
#  'document_label': {'annotation_type': 'document_label',
#                     'annotations': [],
#                     'group_id': 0,
#                     'importance_score': -1},
#  'importance_score': 5.8,
#  'pages': [{'page_label': {'annotation_type': 'page_label',
#                            'annotations': [],
#                            'group_id': 0,
#                            'importance_score': -1},
#             'page_number': '0',
#             'segments': [{'annotation_groups': [{'annotation_type': 'segment_boundary',
#                                                  'annotations': [{'annotation_id': 'r0',
#                                                                   'annotation_vector': ['0.3283 ',
#                                                                                         '0.9312 ',
#                                                                                         '0.6735 ',
#                                                                                         '0.9461 '],
#                                                                   'annotator_id': 'segment_detection_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 0,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'segment_type',
#                                                  'annotations': [{'annotation_id': 'r0',
#                                                                   'annotation_vector': [1.0,
#                                                                                         0.0,
#                                                                                         0.0],
#                                                                   'annotator_id': 'segment_type_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 1,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_truncated',
#                                                  'annotations': [{'annotation_id': 'r0',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'truncation_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 2,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_occluded',
#                                                  'annotations': [{'annotation_id': 'r0',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'occlusion_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 3,
#                                                  'importance_score': None}],
#                           'child_segments': [],
#                           'segment_id': 'r0'},
#                          {'annotation_groups': [{'annotation_type': 'segment_boundary',
#                                                  'annotations': [{'annotation_id': 'r1',
#                                                                   'annotation_vector': ['0.0846 ',
#                                                                                         '0.5947 ',
#                                                                                         '0.2485 ',
#                                                                                         '0.6148 '],
#                                                                   'annotator_id': 'segment_detection_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 0,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'segment_type',
#                                                  'annotations': [{'annotation_id': 'r1',
#                                                                   'annotation_vector': [1.0,
#                                                                                         0.0,
#                                                                                         0.0],
#                                                                   'annotator_id': 'segment_type_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 1,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_truncated',
#                                                  'annotations': [{'annotation_id': 'r1',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'truncation_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 2,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_occluded',
#                                                  'annotations': [{'annotation_id': 'r1',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'occlusion_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 3,
#                                                  'importance_score': None}],
#                           'child_segments': [],
#                           'segment_id': 'r1'},
#                          {'annotation_groups': [{'annotation_type': 'segment_boundary',
#                                                  'annotations': [{'annotation_id': 'r2',
#                                                                   'annotation_vector': ['0.0846 ',
#                                                                                         '0.5643 ',
#                                                                                         '0.2437 ',
#                                                                                         '0.5879 '],
#                                                                   'annotator_id': 'segment_detection_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 0,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'segment_type',
#                                                  'annotations': [{'annotation_id': 'r2',
#                                                                   'annotation_vector': [1.0,
#                                                                                         0.0,
#                                                                                         0.0],
#                                                                   'annotator_id': 'segment_type_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 1,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_truncated',
#                                                  'annotations': [{'annotation_id': 'r2',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'truncation_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 2,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_occluded',
#                                                  'annotations': [{'annotation_id': 'r2',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'occlusion_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 3,
#                                                  'importance_score': None}],
#                           'child_segments': [],
#                           'segment_id': 'r2'},
#                          {'annotation_groups': [{'annotation_type': 'segment_boundary',
#                                                  'annotations': [{'annotation_id': 'r3',
#                                                                   'annotation_vector': ['0.0846 ',
#                                                                                         '0.5323 ',
#                                                                                         '0.3047 ',
#                                                                                         '0.5502 '],
#                                                                   'annotator_id': 'segment_detection_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 0,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'segment_type',
#                                                  'annotations': [{'annotation_id': 'r3',
#                                                                   'annotation_vector': [1.0,
#                                                                                         0.0,
#                                                                                         0.0],
#                                                                   'annotator_id': 'segment_type_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 1,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_truncated',
#                                                  'annotations': [{'annotation_id': 'r3',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'truncation_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 2,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_occluded',
#                                                  'annotations': [{'annotation_id': 'r3',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'occlusion_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 3,
#                                                  'importance_score': None}],
#                           'child_segments': [],
#                           'segment_id': 'r3'},
#                          {'annotation_groups': [{'annotation_type': 'segment_boundary',
#                                                  'annotations': [{'annotation_id': 'r4',
#                                                                   'annotation_vector': ['0.0834 ',
#                                                                                         '0.5036 ',
#                                                                                         '0.5786 ',
#                                                                                         '0.5242 '],
#                                                                   'annotator_id': 'segment_detection_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 0,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'segment_type',
#                                                  'annotations': [{'annotation_id': 'r4',
#                                                                   'annotation_vector': [1.0,
#                                                                                         0.0,
#                                                                                         0.0],
#                                                                   'annotator_id': 'segment_type_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 1,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_truncated',
#                                                  'annotations': [{'annotation_id': 'r4',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'truncation_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 2,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_occluded',
#                                                  'annotations': [{'annotation_id': 'r4',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'occlusion_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 3,
#                                                  'importance_score': None}],
#                           'child_segments': [],
#                           'segment_id': 'r4'},
#                          {'annotation_groups': [{'annotation_type': 'segment_boundary',
#                                                  'annotations': [{'annotation_id': 'r5',
#                                                                   'annotation_vector': ['0.0846 ',
#                                                                                         '0.4587 ',
#                                                                                         '0.8682 ',
#                                                                                         '0.4947 '],
#                                                                   'annotator_id': 'segment_detection_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 0,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'segment_type',
#                                                  'annotations': [{'annotation_id': 'r5',
#                                                                   'annotation_vector': [1.0,
#                                                                                         0.0,
#                                                                                         0.0],
#                                                                   'annotator_id': 'segment_type_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 1,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_truncated',
#                                                  'annotations': [{'annotation_id': 'r5',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'truncation_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 2,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_occluded',
#                                                  'annotations': [{'annotation_id': 'r5',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'occlusion_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 3,
#                                                  'importance_score': None}],
#                           'child_segments': [],
#                           'segment_id': 'r5'},
#                          {'annotation_groups': [{'annotation_type': 'segment_boundary',
#                                                  'annotations': [{'annotation_id': 'r6',
#                                                                   'annotation_vector': ['0.0846 ',
#                                                                                         '0.4297 ',
#                                                                                         '0.8422 ',
#                                                                                         '0.4506 '],
#                                                                   'annotator_id': 'segment_detection_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 0,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'segment_type',
#                                                  'annotations': [{'annotation_id': 'r6',
#                                                                   'annotation_vector': [1.0,
#                                                                                         0.0,
#                                                                                         0.0],
#                                                                   'annotator_id': 'segment_type_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 1,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_truncated',
#                                                  'annotations': [{'annotation_id': 'r6',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'truncation_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 2,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_occluded',
#                                                  'annotations': [{'annotation_id': 'r6',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'occlusion_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 3,
#                                                  'importance_score': None}],
#                           'child_segments': [],
#                           'segment_id': 'r6'},
#                          {'annotation_groups': [{'annotation_type': 'segment_boundary',
#                                                  'annotations': [{'annotation_id': 'r7',
#                                                                   'annotation_vector': ['0.0834 ',
#                                                                                         '0.4010 ',
#                                                                                         '0.8198 ',
#                                                                                         '0.4215 '],
#                                                                   'annotator_id': 'segment_detection_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 0,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'segment_type',
#                                                  'annotations': [{'annotation_id': 'r7',
#                                                                   'annotation_vector': [1.0,
#                                                                                         0.0,
#                                                                                         0.0],
#                                                                   'annotator_id': 'segment_type_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 1,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_truncated',
#                                                  'annotations': [{'annotation_id': 'r7',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'truncation_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 2,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_occluded',
#                                                  'annotations': [{'annotation_id': 'r7',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'occlusion_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 3,
#                                                  'importance_score': None}],
#                           'child_segments': [],
#                           'segment_id': 'r7'},
#                          {'annotation_groups': [{'annotation_type': 'segment_boundary',
#                                                  'annotations': [{'annotation_id': 'r8',
#                                                                   'annotation_vector': ['0.0846 ',
#                                                                                         '0.3715 ',
#                                                                                         '0.3748 ',
#                                                                                         '0.3925 '],
#                                                                   'annotator_id': 'segment_detection_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 0,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'segment_type',
#                                                  'annotations': [{'annotation_id': 'r8',
#                                                                   'annotation_vector': [1.0,
#                                                                                         0.0,
#                                                                                         0.0],
#                                                                   'annotator_id': 'segment_type_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 1,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_truncated',
#                                                  'annotations': [{'annotation_id': 'r8',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'truncation_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 2,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_occluded',
#                                                  'annotations': [{'annotation_id': 'r8',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'occlusion_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 3,
#                                                  'importance_score': None}],
#                           'child_segments': [],
#                           'segment_id': 'r8'},
#                          {'annotation_groups': [{'annotation_type': 'segment_boundary',
#                                                  'annotations': [{'annotation_id': 'r9',
#                                                                   'annotation_vector': ['0.0846 ',
#                                                                                         '0.3378 ',
#                                                                                         '0.3797 ',
#                                                                                         '0.3591 '],
#                                                                   'annotator_id': 'segment_detection_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 0,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'segment_type',
#                                                  'annotations': [{'annotation_id': 'r9',
#                                                                   'annotation_vector': [1.0,
#                                                                                         0.0,
#                                                                                         0.0],
#                                                                   'annotator_id': 'segment_type_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 1,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_truncated',
#                                                  'annotations': [{'annotation_id': 'r9',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'truncation_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 2,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_occluded',
#                                                  'annotations': [{'annotation_id': 'r9',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'occlusion_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 3,
#                                                  'importance_score': None}],
#                           'child_segments': [],
#                           'segment_id': 'r9'},
#                          {'annotation_groups': [{'annotation_type': 'segment_boundary',
#                                                  'annotations': [{'annotation_id': 'r10',
#                                                                   'annotation_vector': ['0.7098 ',
#                                                                                         '0.2971 ',
#                                                                                         '0.9184 ',
#                                                                                         '0.3155 '],
#                                                                   'annotator_id': 'segment_detection_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 0,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'segment_type',
#                                                  'annotations': [{'annotation_id': 'r10',
#                                                                   'annotation_vector': [1.0,
#                                                                                         0.0,
#                                                                                         0.0],
#                                                                   'annotator_id': 'segment_type_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 1,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_truncated',
#                                                  'annotations': [{'annotation_id': 'r10',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'truncation_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 2,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_occluded',
#                                                  'annotations': [{'annotation_id': 'r10',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'occlusion_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 3,
#                                                  'importance_score': None}],
#                           'child_segments': [],
#                           'segment_id': 'r10'},
#                          {'annotation_groups': [{'annotation_type': 'segment_boundary',
#                                                  'annotations': [{'annotation_id': 'r11',
#                                                                   'annotation_vector': ['0.0846 ',
#                                                                                         '0.2518 ',
#                                                                                         '0.2497 ',
#                                                                                         '0.2847 '],
#                                                                   'annotator_id': 'segment_detection_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 0,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'segment_type',
#                                                  'annotations': [{'annotation_id': 'r11',
#                                                                   'annotation_vector': [1.0,
#                                                                                         0.0,
#                                                                                         0.0],
#                                                                   'annotator_id': 'segment_type_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 1,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_truncated',
#                                                  'annotations': [{'annotation_id': 'r11',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'truncation_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 2,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_occluded',
#                                                  'annotations': [{'annotation_id': 'r11',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'occlusion_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 3,
#                                                  'importance_score': None}],
#                           'child_segments': [],
#                           'segment_id': 'r11'},
#                          {'annotation_groups': [{'annotation_type': 'segment_boundary',
#                                                  'annotations': [{'annotation_id': 'r12',
#                                                                   'annotation_vector': ['0.0834 ',
#                                                                                         '0.1779 ',
#                                                                                         '0.3422 ',
#                                                                                         '0.2411 '],
#                                                                   'annotator_id': 'segment_detection_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 0,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'segment_type',
#                                                  'annotations': [{'annotation_id': 'r12',
#                                                                   'annotation_vector': [1.0,
#                                                                                         0.0,
#                                                                                         0.0],
#                                                                   'annotator_id': 'segment_type_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 1,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_truncated',
#                                                  'annotations': [{'annotation_id': 'r12',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'truncation_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 2,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_occluded',
#                                                  'annotations': [{'annotation_id': 'r12',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'occlusion_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 3,
#                                                  'importance_score': None}],
#                           'child_segments': [],
#                           'segment_id': 'r12'},
#                          {'annotation_groups': [{'annotation_type': 'segment_boundary',
#                                                  'annotations': [{'annotation_id': 'r13',
#                                                                   'annotation_vector': ['0.0859 ',
#                                                                                         '0.1492 ',
#                                                                                         '0.4420 ',
#                                                                                         '0.1642 '],
#                                                                   'annotator_id': 'segment_detection_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 0,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'segment_type',
#                                                  'annotations': [{'annotation_id': 'r13',
#                                                                   'annotation_vector': [1.0,
#                                                                                         0.0,
#                                                                                         0.0],
#                                                                   'annotator_id': 'segment_type_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 1,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_truncated',
#                                                  'annotations': [{'annotation_id': 'r13',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'truncation_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 2,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_occluded',
#                                                  'annotations': [{'annotation_id': 'r13',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'occlusion_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 3,
#                                                  'importance_score': None}],
#                           'child_segments': [],
#                           'segment_id': 'r13'},
#                          {'annotation_groups': [{'annotation_type': 'segment_boundary',
#                                                  'annotations': [{'annotation_id': 'r14',
#                                                                   'annotation_vector': ['0.6675 ',
#                                                                                         '0.0654 ',
#                                                                                         '0.9111 ',
#                                                                                         '0.1804 '],
#                                                                   'annotator_id': 'segment_detection_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 0,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'segment_type',
#                                                  'annotations': [{'annotation_id': 'r14',
#                                                                   'annotation_vector': [1.0,
#                                                                                         0.0,
#                                                                                         0.0],
#                                                                   'annotator_id': 'segment_type_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 1,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_truncated',
#                                                  'annotations': [{'annotation_id': 'r14',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'truncation_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 2,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_occluded',
#                                                  'annotations': [{'annotation_id': 'r14',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'occlusion_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 3,
#                                                  'importance_score': None}],
#                           'child_segments': [],
#                           'segment_id': 'r14'},
#                          {'annotation_groups': [{'annotation_type': 'segment_boundary',
#                                                  'annotations': [{'annotation_id': 'r15',
#                                                                   'annotation_vector': ['0.0834 ',
#                                                                                         '0.0415 ',
#                                                                                         '0.2823 ',
#                                                                                         '0.0923 '],
#                                                                   'annotator_id': 'segment_detection_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 0,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'segment_type',
#                                                  'annotations': [{'annotation_id': 'r15',
#                                                                   'annotation_vector': [1.0,
#                                                                                         0.0,
#                                                                                         0.0],
#                                                                   'annotator_id': 'segment_type_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 1,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_truncated',
#                                                  'annotations': [{'annotation_id': 'r15',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'truncation_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 2,
#                                                  'importance_score': None},
#                                                 {'annotation_type': 'is_occluded',
#                                                  'annotations': [{'annotation_id': 'r15',
#                                                                   'annotation_vector': [0.0,
#                                                                                         1.0],
#                                                                   'annotator_id': 'occlusion_model',
#                                                                   'annotator_type': 'model'}],
#                                                  'group_id': 3,
#                                                  'importance_score': None}],
#                           'child_segments': [],
#                           'segment_id': 'r15'}]}]}

# %% [markdown]
# # 7. **AP2 (Annotation Tool):** Annotation is performed by human annotators and documents updated

# %% [markdown]
# # 8. **AP2 (Annotation Tool) -> AP2 (Active Learning):** Documents in collection are updated with human annotation

# %% [markdown]
# # Other stuff

# %% [markdown]
# ## Handling multiple models
# To perform active learning on segment detection the input of multiple models is needed. Two or more models all need to annotate the same segment to determine what segment boundaries need to be annotated by humans. This means the API needs to assign overlapping annotations to the same segment. To test this functionality, two test documents are mocked that are annotated using two models. The first document does not contain any overlapping annotations while the second one does. At the moment, annotations are merged so that each segment consists of up to two annotations, which is the minimum for active learning. An alternative to this would be to merge multiple overlapping annotations into one segment.

# %%
"""
# Custom Boundary Boxes for testing
# Non-Overlapping Segments
# Annotator 1
ad1 = {
    "annotation_id":"1",
    "annotator_id": "test_annotator_1",
    "annotator_type": "model",
    "annotation_vector":[0.00,0.10,0.30,0.40]
}
ad2 = {
    "annotation_id":"2",
    "annotator_id": "test_annotator_1",
    "annotator_type": "model",
    "annotation_vector":[0.35,0.10,0.65,0.40]
}
ad3 = {
    "annotation_id":"3",
    "annotator_id": "test_annotator_1",
    "annotator_type": "model",
    "annotation_vector":[0.70,0.10,1.00,0.40]
}
# Annotator 2
ad4 = {
    "annotation_id":"4",
    "annotator_id": "test_annotator_2",
    "annotator_type": "model",
    "annotation_vector":[0.00,0.60,0.30,0.90]
}
ad5 = {
    "annotation_id":"5",
    "annotator_id": "test_annotator_2",
    "annotator_type": "model",
    "annotation_vector":[0.35,0.60,0.65,0.90]
}

segment_annotations = [ad1, ad2, ad3, ad4, ad5]
page_id_dict["test1.xml"]["0"] = segment_annotations

# Overlapping Segments
# Annotator 1
ad1 = {
    "annotation_id":"1",
    "annotator_id": "test_annotator_1",
    "annotator_type": "model",
    "annotation_vector":[0.00,0.10,0.30,0.40]
}
ad2 = {
    "annotation_id":"2",
    "annotator_id": "test_annotator_1",
    "annotator_type": "model",
    "annotation_vector":[0.35,0.10,0.65,0.40]
}
ad3 = {
    "annotation_id":"3",
    "annotator_id": "test_annotator_1",
    "annotator_type": "model",
    "annotation_vector":[0.70,0.10,1.00,0.40]
}
# Annotator 2
# Overlapping with 1 Segment
ad4 = {
    "annotation_id":"4",
    "annotator_id": "test_annotator_2",
    "annotator_type": "model",
    "annotation_vector":[0.00,0.15,0.30,0.35]
}
# Overlapping with 2 Segments
ad5 = {
    "annotation_id":"5",
    "annotator_id": "test_annotator_2",
    "annotator_type": "model",
    "annotation_vector":[0.40,0.15,0.95,0.35]
}

segment_annotations = [ad1, ad2, ad3, ad4, ad5]
page_id_dict["test2.xml"]["0"] = segment_annotations
"""
# Out:
# '\n# Custom Boundary Boxes for testing\n# Non-Overlapping Segments\n# Annotator 1\nad1 = {\n    "annotation_id":"1",\n    "annotator_id": "test_annotator_1",\n    "annotator_type": "model",\n    "annotation_vector":[0.00,0.10,0.30,0.40]\n}\nad2 = {\n    "annotation_id":"2",\n    "annotator_id": "test_annotator_1",\n    "annotator_type": "model",\n    "annotation_vector":[0.35,0.10,0.65,0.40]\n}\nad3 = {\n    "annotation_id":"3",\n    "annotator_id": "test_annotator_1",\n    "annotator_type": "model",\n    "annotation_vector":[0.70,0.10,1.00,0.40]\n}\n# Annotator 2\nad4 = {\n    "annotation_id":"4",\n    "annotator_id": "test_annotator_2",\n    "annotator_type": "model",\n    "annotation_vector":[0.00,0.60,0.30,0.90]\n}\nad5 = {\n    "annotation_id":"5",\n    "annotator_id": "test_annotator_2",\n    "annotator_type": "model",\n    "annotation_vector":[0.35,0.60,0.65,0.90]\n}\n\nsegment_annotations = [ad1, ad2, ad3, ad4, ad5]\npage_id_dict["test1.xml"]["0"] = segment_annotations\n\n# Overlapping Segments\n# Annotator 1\nad1 = {\n    "annotation_id":"1",\n    "annotator_id": "test_annotator_1",\n    "annotator_type": "model",\n    "annotation_vector":[0.00,0.10,0.30,0.40]\n}\nad2 = {\n    "annotation_id":"2",\n    "annotator_id": "test_annotator_1",\n    "annotator_type": "model",\n    "annotation_vector":[0.35,0.10,0.65,0.40]\n}\nad3 = {\n    "annotation_id":"3",\n    "annotator_id": "test_annotator_1",\n    "annotator_type": "model",\n    "annotation_vector":[0.70,0.10,1.00,0.40]\n}\n# Annotator 2\n# Overlapping with 1 Segment\nad4 = {\n    "annotation_id":"4",\n    "annotator_id": "test_annotator_2",\n    "annotator_type": "model",\n    "annotation_vector":[0.00,0.15,0.30,0.35]\n}\n# Overlapping with 2 Segments\nad5 = {\n    "annotation_id":"5",\n    "annotator_id": "test_annotator_2",\n    "annotator_type": "model",\n    "annotation_vector":[0.40,0.15,0.95,0.35]\n}\n\nsegment_annotations = [ad1, ad2, ad3, ad4, ad5]\npage_id_dict["test2.xml"]["0"] = segment_annotations\n'

# %%
"""
url = "http://localhost:5000/get_document/" + DOCUMENT_IDS[2]
document = json.loads(get_json(url))
pprint(document)"""
# Out:
# '\nurl = "http://localhost:5000/get_document/" + DOCUMENT_IDS[2]\ndocument = json.loads(get_json(url))\npprint(document)'

# %%
"""url = "http://localhost:5000/get_document/" + DOCUMENT_IDS[3]
document = json.loads(get_json(url))
pprint(document)"""
# Out:
# 'url = "http://localhost:5000/get_document/" + DOCUMENT_IDS[3]\ndocument = json.loads(get_json(url))\npprint(document)'
